# %%
from IPython.display import Audio
sound_file = '/home/pablo/Music/Ship_Bell-Mike_Koenig-1911209136.wav'

# %%
from create_clesa_datasets import *
from clesa_classifiers import *
# Out:
# Switching to API Credentials #0

# %%
u = 37226353

# %% [markdown]
# # Vamos a investigar lo siguiente:

# %% [markdown]
# ## ¿ por qué da 0 recall ?

# %% [markdown]
# ## Si genero un dataset balanceado, da algo decente ...

# %%
dataset = load_clesa_dataset_small(u, 1)
model_select_rdf(dataset, cv=2)

# %%
dataset = load_clesa_dataset_small(u, 4)

# %%
model_select_sgd(dataset, cv=4)

# %%
X_train = dataset[0]

# %%
model_select_rdf(dataset, cv=4)

# %% [markdown]
# # Probemos con datos más grandes!!!

# %%
u = 37226353

# %%
dataset = load_clesa_dataset_big(u, 70000)

# %%
clf = SGDClassifier(alpha=0.001, penalty='elasticnet', loss='hinge', n_iter=50)

# clf = RandomForestClassifier(class_weight='balanced',
#                             n_estimators=50, min_samples_leaf=5, max_depth=5,
#                             max_features=300, n_jobs=6)

# %%
model_select_rdf(dataset, cv=4)
# Out:
# # Tuning hyper-parameters for recall

# %%
Audio(sound_file, autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
X_train, X_test, y_train, y_test = dataset

w1 = sum(y_train)/len(y_train)
w0 = 1 - w1
sample_weight = np.array([w0 if x==0 else w1 for x in y_train])

# %%
clf.fit(X_train, y_train, sample_weight=sample_weight)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=5, max_features=300,
#             max_leaf_nodes=None, min_impurity_split=1e-07,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=6,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
evaluate_model(clf, X_train, X_test, y_train, y_test)
Audio(sound_file, autoplay=True)
# Out:
# Detailed classification report:
#
# Scores on training set.
#
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99     68886
#         1.0       0.00      0.00      0.00      1114
#
# avg / total       0.97      0.98      0.98     70000
#
# Scores on test set.
#
#              precision    recall  f1-score   support
#
#         0.0       0.98      1.00      0.99     29546
#         1.0       0.00      0.00      0.00       454
#
# avg / total       0.97      0.98      0.98     30000
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
model_select_svc(dataset, cv=5)

# %%
model_select_sgd(dataset, cv=5)

# %% [markdown]
# ## Pero si la clase 0 es más grande, no (?)

# %%
dataset = load_clesa_dataset_small(u, 2)
model_select_rdf(dataset)

# %%
dataset = load_clesa_dataset_small(u, 3)
model_select_rdf(dataset)

# %%
dataset = load_clesa_dataset_small(u, 4)
model_select_rdf(dataset,cv=2)

# %%
clf = RandomForestClassifier(n_estimators=20, max_depth=50, class_weight='balanced_subsample')

# %%
X_train_clesa, X_test_clesa, y_train, y_test = dataset

# %%
clf.fit(X_train_clesa, y_train)

# %%
print()
print("Scores on training set.")
y_true, y_pred = y_train, clf.predict(X_train_clesa)
print(classification_report(y_true, y_pred))
print()


print("Scores on test set.")
print()
y_true, y_pred = y_test, clf.predict(X_test_clesa)
print(classification_report(y_true, y_pred))
print()
