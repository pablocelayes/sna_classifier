# %%
# !rm /Workspace/Users/pablo.celayes@bolt.eu/learning/sna_classifier/.git/index.lock

# %%
# !pwd

# %%
# !du -sh /Workspace/Users/pablo.celayes@bolt.eu/learning/sna_classifier/experiments/_5_gnn_models_2026/experiments/

# %%
# !ls /Workspace/Users/pablo.celayes@bolt.eu/learning/data/sna_classifier/user_samples_cache | wc -l

# %%
# !du -sh /Workspace/Users/pablo.celayes@bolt.eu/learning/data/sna_classifier/user_samples_cache/

# %%
# !du -sh experiments/*

# %%
DATA_PATH = "/Workspace/Users/pablo.celayes@bolt.eu/learning/data/sna_classifier"

# %%
import json
# Load user splits (same as cell 18 in notebook 2.0)
with open(f"{DATA_PATH}/datasets/user_splits.json") as f:
    user_splits = json.load(f)

# %%
{k: len(v) for k, v in user_splits.items()}

# %%
# !pwd

# %%
# !ls /Workspace/Users/pablo.celayes@bolt.eu/learning/data/sna_classifier/dataframes/2022/raw_sparse | wc -l

# %%
import re

files = [f.name for f in dbutils.fs.ls("file:/Workspace/Users/pablo.celayes@bolt.eu/learning/data/sna_classifier/dataframes/2022/raw_sparse")]

user_file_map = {}
for fname in files:
    m = re.match(r"dfX(train|test)_(\d+)\.pickle", fname)
    if m:
        split, user_id  = m.groups()
        user_file_map.setdefault(user_id, set()).add(split)

user_ids_with_both = [user_id for user_id, splits in user_file_map.items() if {'train', 'test'}.issubset(splits)]

# %%
len(user_ids_with_both)

# %%
user_ids_with_both[:10]

# %%
# !ls /Workspace/Users/pablo.celayes@bolt.eu/learning/data/sna_classifier/dataframes/2022/raw_sparse | grep train | wc -l

# %%
# !ls /Workspace/Users/pablo.celayes@bolt.eu/learning/data/sna_classifier/dataframes/2022/raw_sparse | grep test | wc -l

# %%
'283762641' in user_ids_with_both
